# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()

openai_client = OpenAI(
    base_url="https://api.aicredits.in/v1",
    api_key=os.getenv("AICREDITS_API_KEY"),
)

model = "anthropic/claude-sonnet-4-0"


def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})


def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})


def chat(messages, system=None, temperature=1.0):
    chat_messages = []
    if system:
        chat_messages.append({"role": "system", "content": system})
    chat_messages.extend(messages)

    response = openai_client.chat.completions.create(
        model=model,
        messages=chat_messages,
        max_tokens=1000,
        temperature=temperature,
    )
    return response.choices[0].message.content


# Usage
messages = []
add_user_message(messages, "Generate a one sentence movie Idea")
answer = chat(messages, temperature=1.0)
print(answer)
# Out:
# A retired librarian discovers that every book she's ever read has created an alternate reality, and now she must navigate between these worlds to prevent them from colliding and destroying each other.

# %%
import os
from anthropic import Anthropic
from dotenv import load_dotenv

load_dotenv()

anthropic_client = Anthropic(api_key=os.getenv("ANTHROPIC_API_KEY"))

# Native Anthropic identifier (no 'anthropic/' prefix)
anthropic_model = "claude-3-7-sonnet-latest"


def add_user_message(messages, text):
    messages.append({"role": "user", "content": text})


def add_assistant_message(messages, text):
    messages.append({"role": "assistant", "content": text})


def chat(messages, system=None, temperature=1.0):
    params = {
        "model": anthropic_model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
    }
    if system:
        params["system"] = system

    message = anthropic_client.messages.create(**params)
    return message.content[0].text


# Usage
messages = []
add_user_message(messages, "Generate a one sentence movie Idea")
answer = chat(messages, temperature=0.0)
print(answer)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 38
#      34
#      35 # Usage
#      36 messages = []
#      37 add_user_message(messages, "Generate a one sentence movie Idea")
# ---> 38 answer = chat(messages, temperature=0.0)
#      39 print(answer)
#
# Cell In[4], line 31, in chat(messages, system, temperature)
#      27     }
#      28     if system:
#      29         params["system"] = system
#      30
# ---> 31     message = anthropic_client.messages.create(**params)
#      32     return message.content[0].text
#
# File /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages/anthropic/_utils/_utils.py:294, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     292             msg = f"Missing required argument: {quote(missing[0])}"
#     293     raise TypeError(msg)
# --> 294 return func(*args, **kwargs)
#
# TypeError: Messages.create() got an unexpected keyword argument 'temperature'
