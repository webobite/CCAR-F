# %%
import os
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from openai import OpenAI

# Initialize client pointing to AICredits gateway
openai_client = OpenAI(
    base_url="https://api.aicredits.in/v1",
    api_key=os.getenv("AICREDITS_API_KEY")
)

model = "anthropic/claude-haiku-4.5" 

messages = []

# Helper functions to manage message history
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)

def chat(messages):
    response = openai_client.chat.completions.create(
        model=model,
        max_tokens=1000,
        messages=messages,
    )
    # OpenAI SDK returns text in response.choices[0].message.content
    return response.choices[0].message.content

# %%
while True:
    # Get user input
    user_input = input("> ")
    print(">", user_input)

    # add user input to list of message
    add_user_message(messages, user_input)

    # call claude chat 
    answer = chat(messages)

    add_assistant_message(messages, answer)
    print("BOT: ", answer)
    print("----------------------")
# Out:
# >  What is 208994 + 89
# > What is 208994 + 89
# BOT:  208994 + 89 = 209083
# ----------------------
# >  Print hello world with above message
# > Print hello world with above message
# BOT:  Hello world
# 208994 + 89 = 209083
# ----------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 while True:
#       2     # Get user input
# ----> 3     user_input = input("> ")
#       4     print(">", user_input)
#       5
#       6     # add user input to list of message
#
# File /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages/ipykernel/kernelbase.py:1403, in Kernel.raw_input(self, prompt)
#    1401     msg = "raw_input was called, but this frontend does not support input requests."
#    1402     raise StdinNotImplementedError(msg)
# -> 1403 return self._input_request(
#    1404     str(prompt),
#    1405     self._get_shell_context_var(self._shell_parent_ident),
#    1406     self.get_parent("shell"),
#    1407     password=False,
#    1408 )
#
# File /opt/homebrew/Cellar/jupyterlab/4.6.3/libexec/lib/python3.14/site-packages/ipykernel/kernelbase.py:1448, in Kernel._input_request(self, prompt, ident, parent, password)
#    1445 except KeyboardInterrupt:
#    1446     # re-raise KeyboardInterrupt, to truncate traceback
#    1447     msg = "Interrupted by user"
# -> 1448     raise KeyboardInterrupt(msg) from None
#    1449 except Exception:
#    1450     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
